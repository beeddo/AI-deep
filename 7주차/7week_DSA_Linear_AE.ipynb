# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
df = pd.read_csv("C:/AI/DL/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# ...

# %%
# 사용할 활동 필터링
data = df[df['activity'].isin(['sitting', 'lyingRigh', 'lyingBack'])]
data = data.drop('people', axis=1)
data
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 1915     2.620502      2.6592      2.5891    0.000199    0.014113
# 1916     2.613423      2.6572      2.5815    0.000207    0.014387
# 1917     2.614750      2.6576      2.5654    0.000257    0.016018
# 1918     2.620167      2.6589      2.5781    0.000216    0.014691
# 1919     2.615565      2.6789      2.5734    0.000310    0.017610
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
data['activity'] = label_encoder.fit_transform(data['activity'])

data.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# ...

# %%
# 정상 데이터와 비정상 데이터 통합
data.loc[data['activity'].isin([0, 1]), 'activity'] = 0  # lyingRigh(1)과 lyingBack(0)을 모두 0으로
data.loc[data['activity'] == 2, 'activity'] = 1  # sitting을 1로

# %%
data['activity'].value_counts()
# Out:
# activity
# 0    960
# 1    480
# Name: count, dtype: int64

# %%
# 데이터 정규화
scaler = StandardScaler()
data.iloc[:, :-1] = scaler.fit_transform(data.iloc[:, :-1])  # 'activity' 열 제외하고 정규화

# %%
X = data.drop('activity', axis=1)
X.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     1.168376    1.179659    1.134716    0.424899    1.794701    -0.037407
# 1     1.168870    1.182732    1.166896    0.154077    1.031924     0.987842
# 2     1.167436    1.165165    1.166857   -0.022360    0.310479     0.183152
# 3     1.161106    1.169503    1.136238    0.004198    0.442800    -0.408865
# 4     1.155360    1.173822    1.163969   -0.075787   -0.009354     3.640945
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  LL_ymag_min  \
# 0     1.064111    1.057739    1.076760   -0.084875  ...    -0.025631
# 1     1.078602    1.065174    1.092044   -0.152909  ...    -0.025487
# 2     1.078626    1.065149    1.097461   -0.166074  ...    -0.023241
# 3     1.084727    1.091232    1.097234   -0.086558  ...    -0.022763
# 4     1.090312    1.076313    1.101215   -0.158700  ...    -0.023886
#
#    LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# ...

# %%
y = data['activity']
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: activity, dtype: int32

# %%
# 훈련 데이터와 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %%
# 정상 데이터만 훈련에 사용
X_train = X_train[y_train == 0].values  # 정상 데이터만 사용

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 16  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 270)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │           4,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │              72 │
# ...

# %%
# 모델 학습
history = autoencoder.fit(X_train, X_train, 
                          epochs=50, 
                          batch_size=256, 
                          shuffle=True, 
                          validation_split=0.1)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 1.1086 - val_loss: 0.8487
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2863 - val_loss: 0.8455
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2407 - val_loss: 0.8416
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4375 - val_loss: 0.8367
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1477 - val_loss: 0.8305
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3501 - val_loss: 0.8229
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2416 - val_loss: 0.8138
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3249 - val_loss: 0.8028
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1077 - val_loss: 0.7898
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2940 - val_loss: 0.7749
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3414 - val_loss: 0.7579
# Epoch 12/50
# ...

# %%
# 손실 그래프 시각화
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# 테스트 데이터에 대해 예측 수행
predictions = autoencoder.predict(X_test)

# 재구성 오류 계산 (MSE)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,'true_class': y_test})

error_df.describe()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step
#        reconstruction_error  true_class
# count            288.000000  288.000000
# mean               0.873127    0.340278
# std                2.233527    0.474627
# min                0.179906    0.000000
# 25%                0.351758    0.000000
# 50%                0.509729    0.000000
# 75%                0.659263    1.000000
# max               24.729561    1.000000

# %%
# 임계값 설정 (적절히 조정)
threshold = 0.540098

# %%
# 예측 수행
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]

# %%
# 정확도 평가
accuracy = np.mean(y_pred == error_df.true_class)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 74.65%

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# 혼동 행렬 계산
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

# 혼동 행렬 시각화
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap='Blues', xticklabels=['Normal', 'Abnormal'], yticklabels=['Normal', 'Abnormal'])
plt.title("Confusion Matrix")
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.show()

# 정확도 및 분류 리포트 출력
print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.72      0.79       190
#            1       0.60      0.80      0.68        98
#
#     accuracy                           0.75       288
#    macro avg       0.73      0.76      0.74       288
# weighted avg       0.78      0.75      0.75       288
