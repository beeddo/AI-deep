# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# 데이터 로드
df = pd.read_csv("C:/AI/DL/abalone.csv", index_col=0)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# 결측치 확인 및 제거
df = df.dropna()

# %%
# 성별 인코딩
label = LabelEncoder()
df['Sex'] = label.fit_transform(df['Sex'])
df
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# 레이블 설정
y = df['Rings'].values  
X = df.drop('Rings', axis=1)

# %%
# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
X_train.shape, y_train.shape, X_test.shape, y_test.shape,
# Out:
# ((3132, 8), (3132,), (1045, 8), (1045,))

# %%
# 데이터 스케일링
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 입력 데이터 형태 변환
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# CNN 모델
model = keras.models.Sequential()
model.add(keras.layers.LSTM(50, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(keras.layers.Dense(1))

# 모델 컴파일
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
# Out:
# C:\Users\tpfzl\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 모델 훈련
model_history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 84.2491 - mae: 8.3133 - val_loss: 10.2526 - val_mae: 2.2900
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.9594 - mae: 2.2062 - val_loss: 7.2952 - val_mae: 1.8909
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3025 - mae: 2.0435 - val_loss: 6.8510 - val_mae: 1.8438
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4890 - mae: 1.9876 - val_loss: 6.9034 - val_mae: 1.8057
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8254 - mae: 1.8907 - val_loss: 6.6091 - val_mae: 1.8258
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6577 - mae: 1.9804 - val_loss: 7.1232 - val_mae: 1.7798
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2184 - mae: 1.9235 - val_loss: 6.4834 - val_mae: 1.8926
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9729 - mae: 1.9356 - val_loss: 6.5758 - val_mae: 1.7900
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3917 - mae: 1.9494 - val_loss: 6.6222 - val_mae: 1.9817
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3035 - mae: 1.9817 - val_loss: 6.5122 - val_mae: 1.7646
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1805 - mae: 1.9178 - val_loss: 6.3858 - val_mae: 1.8309
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2725 - mae: 1.9777 - val_loss: 6.3817 - val_mae: 1.8337
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4741 - mae: 1.9399 - val_loss: 6.3739 - val_mae: 1.7765
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0133 - mae: 1.8960 - val_loss: 6.2671 - val_mae: 1.8366
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3940 - mae: 1.8394 - val_loss: 6.3020 - val_mae: 1.8799
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6964 - mae: 1.8775 - val_loss: 6.8559 - val_mae: 2.0828
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9239 - mae: 1.9146 - val_loss: 6.6399 - val_mae: 2.0112
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9548 - mae: 1.9746 - val_loss: 6.1436 - val_mae: 1.7961
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6618 - mae: 1.8965 - val_loss: 6.2653 - val_mae: 1.7395
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7575 - mae: 1.8655 - val_loss: 6.0571 - val_mae: 1.7640
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4732 - mae: 1.8205 - val_loss: 5.9906 - val_mae: 1.7351
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1186 - mae: 1.7865 - val_loss: 5.9362 - val_mae: 1.7826
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0197 - mae: 1.7651 - val_loss: 5.8367 - val_mae: 1.8027
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6201 - mae: 1.8674 - val_loss: 6.3324 - val_mae: 1.9938
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7686 - mae: 1.7590 - val_loss: 5.6671 - val_mae: 1.8112
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6557 - mae: 1.7498 - val_loss: 5.3007 - val_mae: 1.6162
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6070 - mae: 1.7030 - val_loss: 5.4053 - val_mae: 1.5968
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6636 - mae: 1.7364 - val_loss: 5.0064 - val_mae: 1.5837
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0716 - mae: 1.6308 - val_loss: 4.8812 - val_mae: 1.5615
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9196 - mae: 1.5839 - val_loss: 4.8292 - val_mae: 1.5657
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6635 - mae: 1.5462 - val_loss: 4.8012 - val_mae: 1.5352
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1068 - mae: 1.6327 - val_loss: 4.8526 - val_mae: 1.5374
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0653 - mae: 1.6197 - val_loss: 4.8122 - val_mae: 1.6233
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9233 - mae: 1.6197 - val_loss: 4.6939 - val_mae: 1.5339
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9816 - mae: 1.6289 - val_loss: 4.7832 - val_mae: 1.5041
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6802 - mae: 1.5592 - val_loss: 5.0296 - val_mae: 1.5316
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5884 - mae: 1.5577 - val_loss: 4.6411 - val_mae: 1.5614
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4738 - mae: 1.5417 - val_loss: 4.5940 - val_mae: 1.5395
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4974 - mae: 1.5251 - val_loss: 4.5237 - val_mae: 1.5048
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5611 - mae: 1.5467 - val_loss: 4.5111 - val_mae: 1.5062
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2942 - mae: 1.4863 - val_loss: 4.6206 - val_mae: 1.5652
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4198 - mae: 1.5082 - val_loss: 4.5375 - val_mae: 1.5294
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5676 - mae: 1.5284 - val_loss: 4.5568 - val_mae: 1.5501
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7708 - mae: 1.5684 - val_loss: 4.5660 - val_mae: 1.4937
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8300 - mae: 1.6096 - val_loss: 4.4983 - val_mae: 1.4825
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6066 - mae: 1.5316 - val_loss: 4.6668 - val_mae: 1.5939
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6304 - mae: 1.5556 - val_loss: 4.4352 - val_mae: 1.4926
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5023 - mae: 1.5270 - val_loss: 4.4773 - val_mae: 1.5172
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1578 - mae: 1.4744 - val_loss: 4.6269 - val_mae: 1.5849
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5891 - mae: 1.5404 - val_loss: 4.6098 - val_mae: 1.4763

# %%
# 예측
y_pred = model.predict(X_test)

# 성능 평가
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'Mean Squared Error: {mse:.4f}')
print(f'Mean Absolute Error: {mae:.4f}')
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Mean Squared Error: 4.6172
# Mean Absolute Error: 1.4763

# %%
# loss 체크
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(range(50), model_history.history['loss'], label='train loss')
plt.plot(range(50), model_history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3157 - mae: 1.4362
# [4.609764099121094, 1.476258635520935]
